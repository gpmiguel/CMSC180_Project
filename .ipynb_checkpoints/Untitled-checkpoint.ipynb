# %%
import pandas as pd

import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np

# %%
bubbleSortData = pd.read_csv("./Bubble Sort/Serial/bubbleSort.csv") 
pBubbleSortData = pd.read_csv("./Bubble Sort/Parallel/pBubbleSort.csv") 

bucketSortData = pd.read_csv("./Bucket Sort/Serial/bucketSort.csv") 
pBucketSortData = pd.read_csv("./Bucket Sort/Parallel/pBucketSort.csv") 

mergeSortData = pd.read_csv("./Merge Sort/Serial/mergeSort.csv") 
pMergeSortData = pd.read_csv("./Merge Sort/Parallel/pMergeSort.csv") 

shellSortData = pd.read_csv("./Shell Sort/Serial/shellSort.csv") 
pShellSortData = pd.read_csv("./Shell Sort/Parallel/pShellSort.csv")

# %%
print(bubbleSortData)

x = bubbleSortData.N
y = bubbleSortData.seconds
plt.scatter(x, y)

plt.xlabel("Sizes of N")
plt.ylabel("Running Time (seconds)")

plt.show()
# Out:
#           N      seconds
# 0      1000     0.003565
# 1      2000     0.015141
# 2      3000     0.046855
# 3      4000     0.070342
# 4      5000     0.091506
# ..      ...          ...
# 152  300000   361.664997
# 153  350000   493.202313
# 154  400000   646.312885
# 155  450000   816.135620
# 156  500000  1009.396752
#
# [157 rows x 2 columns]
#           N     seconds
# 0      1000    0.002737
# 1      2000    0.014749
# 2      3000    0.026869
# 3      4000    0.041710
# 4      5000    0.074271
# ..      ...         ...
# 152  300000  133.300126
# 153  350000  182.674666
# 154  400000  238.441803
# 155  450000  302.325225
# 156  500000  376.107021
#
# [157 rows x 2 columns]

# %%
print(pBubbleSortData)

x = pBubbleSortData.N
y = pBubbleSortData.seconds
plt.scatter(x, y)

plt.xlabel("Sizes of N")
plt.ylabel("Running Time (seconds)")

plt.show()
# Out:
#           N     seconds
# 0      1000    0.002737
# 1      2000    0.014749
# 2      3000    0.026869
# 3      4000    0.041710
# 4      5000    0.074271
# ..      ...         ...
# 152  300000  133.300126
# 153  350000  182.674666
# 154  400000  238.441803
# 155  450000  302.325225
# 156  500000  376.107021
#
# [157 rows x 2 columns]

# %%
print(bucketSortData)

x = bucketSortData.N
y = bucketSortData.seconds
plt.scatter(x, y)

plt.xlabel("Sizes of N")
plt.ylabel("Running Time (seconds)")

plt.show()
# Out:
#           N   seconds
# 0      1000  0.000284
# 1      2000  0.000408
# 2      3000  0.000658
# 3      4000  0.000885
# 4      5000  0.001252
# ..      ...       ...
# 495  496000  0.138325
# 496  497000  0.142718
# 497  498000  0.140376
# 498  499000  0.140826
# 499  500000  0.139942
#
# [500 rows x 2 columns]

# %%
print(mergeSortData)

x = mergeSortData.N
y = mergeSortData.seconds
plt.scatter(x, y)

plt.xlabel("Sizes of N")
plt.ylabel("Running Time (seconds)")

plt.show()
# Out:
#           N   seconds
# 0      1000  0.000199
# 1      2000  0.000412
# 2      3000  0.000643
# 3      4000  0.000968
# 4      5000  0.001359
# ..      ...       ...
# 495  496000  0.141548
# 496  497000  0.142820
# 497  498000  0.142398
# 498  499000  0.146815
# 499  500000  0.142028
#
# [500 rows x 2 columns]

# %%
print(pMergeSortData)

x = pMergeSortData.N
y = pMergeSortData.seconds
plt.scatter(x, y)

plt.xlabel("Sizes of N")
plt.ylabel("Running Time (seconds)")

plt.show()
# Out:
#           N   seconds
# 0      1000  0.000596
# 1      2000  0.001475
# 2      3000  0.001011
# 3      4000  0.001406
# 4      5000  0.000998
# ..      ...       ...
# 495  496000  0.115121
# 496  497000  0.110450
# 497  498000  0.116278
# 498  499000  0.116118
# 499  500000  0.111258
#
# [500 rows x 2 columns]

# %%
print(pBucketSortData)

x = pBucketSortData.N
y = pBucketSortData.seconds
plt.scatter(x, y)

plt.xlabel("Sizes of N")
plt.ylabel("Running Time (seconds)")

plt.show()
# Out:
#           N   seconds
# 0      1000  0.000394
# 1      2000  0.000429
# 2      3000  0.000565
# 3      4000  0.000741
# 4      5000  0.000801
# ..      ...       ...
# 495  496000  0.112610
# 496  497000  0.108716
# 497  498000  0.114992
# 498  499000  0.115469
# 499  500000  0.113533
#
# [500 rows x 2 columns]

# %%
print(shellSortData)

x = shellSortData.N
y = shellSortData.seconds
plt.scatter(x, y)

plt.xlabel("Sizes of N")
plt.ylabel("Running Time (seconds)")

plt.show()
# Out:
#           N   seconds
# 0      1000  0.000222
# 1      2000  0.000794
# 2      3000  0.000728
# 3      4000  0.001036
# 4      5000  0.001377
# ..      ...       ...
# 495  496000  0.267397
# 496  497000  0.277344
# 497  498000  0.271564
# 498  499000  0.266561
# 499  500000  0.273855
#
# [500 rows x 2 columns]

# %%
print(pShellSortData)

x = pShellSortData.N
y = pShellSortData.seconds
plt.scatter(x, y)

plt.xlabel("Sizes of N")
plt.ylabel("Running Time (seconds)")

plt.show()
# Out:
#           N   seconds
# 0      1000  0.000389
# 1      2000  0.000415
# 2      3000  0.000580
# 3      4000  0.000737
# 4      5000  0.000857
# ..      ...       ...
# 495  496000  0.274171
# 496  497000  0.314713
# 497  498000  0.224578
# 498  499000  0.281467
# 499  500000  0.194552
#
# [500 rows x 2 columns]
